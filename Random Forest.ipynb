# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.pipeline import Pipeline
from pyspark.ml.classification import RandomForestClassifier

import pandas as pd
import numpy as np

# %%
spark = SparkSession.builder.appName('RandomForest').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-NKF58JP:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>RandomForest</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
filename = 'data/bank-full.csv'

# %%
data = spark.read.csv(filename, header=True, inferSchema=True, sep=';')

# %%
data.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- y: string (nullable = true)

# %%
# assembling the feature:

def assemble_vector(df, features_list, target):
    
    assembler = VectorAssembler(inputCols=features_list, outputCol='features')
    string_indexer = StringIndexer(inputCol=target, outputCol=target+'_index')
    stages = [assembler, string_indexer]
    
    selected_cols = [target+'_index', 'features'] + features_list
    
    pipeline = Pipeline(stages=stages)
    assemble_model = pipeline.fit(df)
    df = assemble_model.transform(df).select(selected_cols)
    return df

# %%
# features and target:
target_variable_name = 'y'
rf_df = data.select(['age', 'balance', 'day', 'duration',
                          'campaign', 'pdays', 'previous', 'y'])

features_list = rf_df.columns
features_list.remove(target_variable_name)

# %%
# applying the function:
df = assemble_vector(data, features_list, target_variable_name)

# %%
# building the instance 
rf = RandomForestClassifier(featuresCol='features', labelCol='y_index')

# %%
# training the model on the data:
rf_model = rf.fit(df)

# %%
# looking at the feature importance:
print(f"Feature Importance:\n {rf_model.featureImportances}")
# Out:
# Feature Importance:
#  (7,[0,1,2,3,4,5,6],[0.08584434644644709,0.011033366860813895,0.015559015434628657,0.6793873016945361,0.004066526221407603,0.14272552678180514,0.06138391656036157])

# %%
# looking at the tree decisions:
print(rf_model.toDebugString)
# Out:
# RandomForestClassificationModel: uid=RandomForestClassifier_278ff0c65c30, numTrees=20, numClasses=2, numFeatures=7
#   Tree 0 (weight 1.0):
#     If (feature 3 <= 435.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 9.0)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 252.5)
#          Predict: 0.0
#         Else (feature 3 > 252.5)
#          Predict: 1.0
#       Else (feature 5 > 9.0)
#        If (feature 0 <= 58.5)
#         Predict: 0.0
#        Else (feature 0 > 58.5)
#         If (feature 5 <= 192.5)
#          Predict: 1.0
#         Else (feature 5 > 192.5)
#          Predict: 0.0
#     Else (feature 3 > 435.5)
#      If (feature 3 <= 692.5)
#       If (feature 6 <= 0.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         Predict: 1.0
#       Else (feature 6 > 0.5)
#        If (feature 0 <= 48.5)
#         If (feature 5 <= 98.5)
#          Predict: 1.0
#         Else (feature 5 > 98.5)
#          Predict: 0.0
#        Else (feature 0 > 48.5)
#         If (feature 1 <= -0.5)
#          Predict: 0.0
#         Else (feature 1 > -0.5)
#          Predict: 1.0
#      Else (feature 3 > 692.5)
#       If (feature 3 <= 920.5)
#        If (feature 6 <= 0.5)
#         If (feature 1 <= 934.5)
#          Predict: 0.0
#         Else (feature 1 > 934.5)
#          Predict: 1.0
#        Else (feature 6 > 0.5)
#         Predict: 1.0
#       Else (feature 3 > 920.5)
#        If (feature 1 <= 10.5)
#         If (feature 4 <= 10.5)
#          Predict: 1.0
#         Else (feature 4 > 10.5)
#          Predict: 0.0
#        Else (feature 1 > 10.5)
#         If (feature 5 <= 347.5)
#          Predict: 1.0
#         Else (feature 5 > 347.5)
#          Predict: 0.0
#   Tree 1 (weight 1.0):
#     If (feature 0 <= 60.5)
#      If (feature 3 <= 583.5)
#       Predict: 0.0
#      Else (feature 3 > 583.5)
#       If (feature 3 <= 920.5)
#        If (feature 5 <= -0.5)
#         Predict: 0.0
#        Else (feature 5 > -0.5)
#         If (feature 2 <= 23.5)
#          Predict: 0.0
#         Else (feature 2 > 23.5)
#          Predict: 1.0
#       Else (feature 3 > 920.5)
#        If (feature 0 <= 29.5)
#         If (feature 5 <= 347.5)
#          Predict: 1.0
#         Else (feature 5 > 347.5)
#          Predict: 0.0
#        Else (feature 0 > 29.5)
#         Predict: 1.0
#     Else (feature 0 > 60.5)
#      If (feature 2 <= 12.5)
#       If (feature 1 <= 2955.5)
#        If (feature 3 <= 193.5)
#         Predict: 0.0
#        Else (feature 3 > 193.5)
#         If (feature 6 <= 3.5)
#          Predict: 1.0
#         Else (feature 6 > 3.5)
#          Predict: 0.0
#       Else (feature 1 > 2955.5)
#        If (feature 2 <= 2.5)
#         If (feature 1 <= 3765.5)
#          Predict: 0.0
#         Else (feature 1 > 3765.5)
#          Predict: 1.0
#        Else (feature 2 > 2.5)
#         Predict: 0.0
#      Else (feature 2 > 12.5)
#       If (feature 5 <= 170.5)
#        Predict: 0.0
#       Else (feature 5 > 170.5)
#        Predict: 1.0
#   Tree 2 (weight 1.0):
#     If (feature 5 <= 9.0)
#      If (feature 3 <= 496.5)
#       If (feature 3 <= 221.5)
#        Predict: 0.0
#       Else (feature 3 > 221.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 294.5)
#          Predict: 0.0
#         Else (feature 3 > 294.5)
#          Predict: 1.0
#      Else (feature 3 > 496.5)
#       If (feature 3 <= 692.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 2 <= 10.5)
#          Predict: 0.0
#         Else (feature 2 > 10.5)
#          Predict: 1.0
#       Else (feature 3 > 692.5)
#        If (feature 4 <= 11.5)
#         Predict: 1.0
#        Else (feature 4 > 11.5)
#         If (feature 0 <= 27.5)
#          Predict: 1.0
#         Else (feature 0 > 27.5)
#          Predict: 0.0
#     Else (feature 5 > 9.0)
#      If (feature 2 <= 21.5)
#       If (feature 2 <= 16.5)
#        Predict: 0.0
#       Else (feature 2 > 16.5)
#        If (feature 2 <= 20.5)
#         Predict: 0.0
#        Else (feature 2 > 20.5)
#         If (feature 0 <= 29.5)
#          Predict: 1.0
#         Else (feature 0 > 29.5)
#          Predict: 0.0
#      Else (feature 2 > 21.5)
#       If (feature 1 <= 2955.5)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         If (feature 2 <= 27.5)
#          Predict: 1.0
#         Else (feature 2 > 27.5)
#          Predict: 0.0
#       Else (feature 1 > 2955.5)
#        If (feature 3 <= 169.5)
#         Predict: 0.0
#        Else (feature 3 > 169.5)
#         Predict: 1.0
#   Tree 3 (weight 1.0):
#     If (feature 3 <= 496.5)
#      If (feature 6 <= 0.5)
#       Predict: 0.0
#      Else (feature 6 > 0.5)
#       If (feature 3 <= 158.5)
#        Predict: 0.0
#       Else (feature 3 > 158.5)
#        If (feature 5 <= 98.5)
#         Predict: 1.0
#        Else (feature 5 > 98.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#     Else (feature 3 > 496.5)
#      If (feature 3 <= 920.5)
#       If (feature 3 <= 692.5)
#        If (feature 5 <= -0.5)
#         Predict: 0.0
#        Else (feature 5 > -0.5)
#         If (feature 0 <= 54.5)
#          Predict: 0.0
#         Else (feature 0 > 54.5)
#          Predict: 1.0
#       Else (feature 3 > 692.5)
#        If (feature 1 <= 1723.5)
#         If (feature 0 <= 32.5)
#          Predict: 1.0
#         Else (feature 0 > 32.5)
#          Predict: 0.0
#        Else (feature 1 > 1723.5)
#         Predict: 1.0
#      Else (feature 3 > 920.5)
#       If (feature 6 <= 7.5)
#        If (feature 1 <= 7581.5)
#         Predict: 1.0
#        Else (feature 1 > 7581.5)
#         If (feature 2 <= 11.5)
#          Predict: 0.0
#         Else (feature 2 > 11.5)
#          Predict: 1.0
#       Else (feature 6 > 7.5)
#        Predict: 0.0
#   Tree 4 (weight 1.0):
#     If (feature 3 <= 496.5)
#      If (feature 5 <= 9.0)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 129.5)
#         Predict: 0.0
#        Else (feature 3 > 129.5)
#         If (feature 3 <= 294.5)
#          Predict: 0.0
#         Else (feature 3 > 294.5)
#          Predict: 1.0
#      Else (feature 5 > 9.0)
#       If (feature 5 <= 98.5)
#        If (feature 4 <= 3.5)
#         If (feature 3 <= 148.5)
#          Predict: 0.0
#         Else (feature 3 > 148.5)
#          Predict: 1.0
#        Else (feature 4 > 3.5)
#         Predict: 0.0
#       Else (feature 5 > 98.5)
#        Predict: 0.0
#     Else (feature 3 > 496.5)
#      If (feature 6 <= 0.5)
#       If (feature 3 <= 692.5)
#        Predict: 0.0
#       Else (feature 3 > 692.5)
#        If (feature 0 <= 32.5)
#         If (feature 3 <= 920.5)
#          Predict: 0.0
#         Else (feature 3 > 920.5)
#          Predict: 1.0
#        Else (feature 0 > 32.5)
#         If (feature 1 <= 458.5)
#          Predict: 0.0
#         Else (feature 1 > 458.5)
#          Predict: 1.0
#      Else (feature 6 > 0.5)
#       If (feature 5 <= 98.5)
#        Predict: 1.0
#       Else (feature 5 > 98.5)
#        If (feature 3 <= 583.5)
#         If (feature 0 <= 54.5)
#          Predict: 0.0
#         Else (feature 0 > 54.5)
#          Predict: 1.0
#        Else (feature 3 > 583.5)
#         If (feature 0 <= 33.5)
#          Predict: 0.0
#         Else (feature 0 > 33.5)
#          Predict: 1.0
#   Tree 5 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 3 <= 496.5)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 129.5)
#         Predict: 0.0
#        Else (feature 3 > 129.5)
#         If (feature 3 <= 236.5)
#          Predict: 0.0
#         Else (feature 3 > 236.5)
#          Predict: 1.0
#      Else (feature 3 > 496.5)
#       If (feature 1 <= 527.5)
#        If (feature 2 <= 29.5)
#         Predict: 0.0
#        Else (feature 2 > 29.5)
#         If (feature 1 <= 0.5)
#          Predict: 0.0
#         Else (feature 1 > 0.5)
#          Predict: 1.0
#       Else (feature 1 > 527.5)
#        Predict: 0.0
#     Else (feature 6 > 0.5)
#      If (feature 5 <= 98.5)
#       If (feature 2 <= 2.5)
#        If (feature 3 <= 389.5)
#         Predict: 0.0
#        Else (feature 3 > 389.5)
#         If (feature 0 <= 27.5)
#          Predict: 0.0
#         Else (feature 0 > 27.5)
#          Predict: 1.0
#       Else (feature 2 > 2.5)
#        If (feature 5 <= 42.0)
#         Predict: 0.0
#        Else (feature 5 > 42.0)
#         If (feature 3 <= 129.5)
#          Predict: 0.0
#         Else (feature 3 > 129.5)
#          Predict: 1.0
#      Else (feature 5 > 98.5)
#       If (feature 3 <= 181.5)
#        Predict: 0.0
#       Else (feature 3 > 181.5)
#        If (feature 3 <= 389.5)
#         Predict: 0.0
#        Else (feature 3 > 389.5)
#         If (feature 3 <= 692.5)
#          Predict: 0.0
#         Else (feature 3 > 692.5)
#          Predict: 1.0
#   Tree 6 (weight 1.0):
#     If (feature 5 <= 9.0)
#      If (feature 1 <= 235.5)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 29.5)
#         If (feature 3 <= 294.5)
#          Predict: 0.0
#         Else (feature 3 > 294.5)
#          Predict: 1.0
#        Else (feature 2 > 29.5)
#         If (feature 3 <= 272.5)
#          Predict: 1.0
#         Else (feature 3 > 272.5)
#          Predict: 0.0
#      Else (feature 1 > 235.5)
#       If (feature 2 <= 1.5)
#        If (feature 3 <= 158.5)
#         Predict: 0.0
#        Else (feature 3 > 158.5)
#         If (feature 0 <= 28.5)
#          Predict: 1.0
#         Else (feature 0 > 28.5)
#          Predict: 0.0
#       Else (feature 2 > 1.5)
#        Predict: 0.0
#     Else (feature 5 > 9.0)
#      If (feature 3 <= 181.5)
#       Predict: 0.0
#      Else (feature 3 > 181.5)
#       If (feature 5 <= 192.5)
#        If (feature 5 <= 98.5)
#         If (feature 5 <= 39.0)
#          Predict: 0.0
#         Else (feature 5 > 39.0)
#          Predict: 1.0
#        Else (feature 5 > 98.5)
#         Predict: 0.0
#       Else (feature 5 > 192.5)
#        If (feature 1 <= 934.5)
#         Predict: 0.0
#        Else (feature 1 > 934.5)
#         If (feature 2 <= 20.5)
#          Predict: 0.0
#         Else (feature 2 > 20.5)
#          Predict: 1.0
#   Tree 7 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 4 <= 4.5)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         If (feature 1 <= 38.5)
#          Predict: 0.0
#         Else (feature 1 > 38.5)
#          Predict: 1.0
#      Else (feature 4 > 4.5)
#       If (feature 0 <= 60.5)
#        If (feature 2 <= 1.5)
#         Predict: 1.0
#        Else (feature 2 > 1.5)
#         Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 13.5)
#         Predict: 0.0
#        Else (feature 2 > 13.5)
#         If (feature 3 <= 294.5)
#          Predict: 0.0
#         Else (feature 3 > 294.5)
#          Predict: 1.0
#     Else (feature 6 > 0.5)
#      If (feature 3 <= 207.5)
#       If (feature 5 <= 98.5)
#        If (feature 3 <= 138.5)
#         Predict: 0.0
#        Else (feature 3 > 138.5)
#         If (feature 4 <= 1.5)
#          Predict: 1.0
#         Else (feature 4 > 1.5)
#          Predict: 0.0
#       Else (feature 5 > 98.5)
#        Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 0 <= 58.5)
#        If (feature 2 <= 21.5)
#         Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 1 <= 1445.5)
#          Predict: 0.0
#         Else (feature 1 > 1445.5)
#          Predict: 1.0
#       Else (feature 0 > 58.5)
#        If (feature 0 <= 60.5)
#         If (feature 5 <= 347.5)
#          Predict: 0.0
#         Else (feature 5 > 347.5)
#          Predict: 1.0
#        Else (feature 0 > 60.5)
#         If (feature 5 <= 36.0)
#          Predict: 0.0
#         Else (feature 5 > 36.0)
#          Predict: 1.0
#   Tree 8 (weight 1.0):
#     If (feature 0 <= 60.5)
#      If (feature 3 <= 496.5)
#       If (feature 5 <= 12.5)
#        Predict: 0.0
#       Else (feature 5 > 12.5)
#        If (feature 5 <= 98.5)
#         If (feature 3 <= 148.5)
#          Predict: 0.0
#         Else (feature 3 > 148.5)
#          Predict: 1.0
#        Else (feature 5 > 98.5)
#         Predict: 0.0
#      Else (feature 3 > 496.5)
#       If (feature 3 <= 692.5)
#        Predict: 0.0
#       Else (feature 3 > 692.5)
#        If (feature 2 <= 29.5)
#         Predict: 1.0
#        Else (feature 2 > 29.5)
#         If (feature 2 <= 30.5)
#          Predict: 1.0
#         Else (feature 2 > 30.5)
#          Predict: 0.0
#     Else (feature 0 > 60.5)
#      If (feature 5 <= 170.5)
#       If (feature 3 <= 207.5)
#        Predict: 0.0
#       Else (feature 3 > 207.5)
#        If (feature 1 <= 391.5)
#         Predict: 0.0
#        Else (feature 1 > 391.5)
#         If (feature 1 <= 5057.5)
#          Predict: 1.0
#         Else (feature 1 > 5057.5)
#          Predict: 0.0
#      Else (feature 5 > 170.5)
#       If (feature 6 <= 1.5)
#        If (feature 4 <= 4.5)
#         Predict: 0.0
#        Else (feature 4 > 4.5)
#         Predict: 1.0
#       Else (feature 6 > 1.5)
#        If (feature 5 <= 347.5)
#         If (feature 2 <= 1.5)
#          Predict: 0.0
#         Else (feature 2 > 1.5)
#          Predict: 1.0
#        Else (feature 5 > 347.5)
#         If (feature 3 <= 322.5)
#          Predict: 0.0
#         Else (feature 3 > 322.5)
#          Predict: 1.0
#   Tree 9 (weight 1.0):
#     If (feature 5 <= -0.5)
#      If (feature 4 <= 1.5)
#       Predict: 0.0
#      Else (feature 4 > 1.5)
#       If (feature 3 <= 583.5)
#        Predict: 0.0
#       Else (feature 3 > 583.5)
#        If (feature 0 <= 30.5)
#         If (feature 2 <= 19.5)
#          Predict: 1.0
#         Else (feature 2 > 19.5)
#          Predict: 0.0
#        Else (feature 0 > 30.5)
#         If (feature 3 <= 920.5)
#          Predict: 0.0
#         Else (feature 3 > 920.5)
#          Predict: 1.0
#     Else (feature 5 > -0.5)
#      If (feature 3 <= 181.5)
#       Predict: 0.0
#      Else (feature 3 > 181.5)
#       If (feature 0 <= 58.5)
#        If (feature 3 <= 435.5)
#         Predict: 0.0
#        Else (feature 3 > 435.5)
#         If (feature 5 <= 98.5)
#          Predict: 1.0
#         Else (feature 5 > 98.5)
#          Predict: 0.0
#       Else (feature 0 > 58.5)
#        If (feature 4 <= 1.5)
#         If (feature 2 <= 7.5)
#          Predict: 0.0
#         Else (feature 2 > 7.5)
#          Predict: 1.0
#        Else (feature 4 > 1.5)
#         If (feature 3 <= 322.5)
#          Predict: 0.0
#         Else (feature 3 > 322.5)
#          Predict: 1.0
#   Tree 10 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 0 <= 60.5)
#       If (feature 3 <= 496.5)
#        Predict: 0.0
#       Else (feature 3 > 496.5)
#        If (feature 1 <= 148.5)
#         If (feature 3 <= 920.5)
#          Predict: 0.0
#         Else (feature 3 > 920.5)
#          Predict: 1.0
#        Else (feature 1 > 148.5)
#         Predict: 0.0
#      Else (feature 0 > 60.5)
#       If (feature 3 <= 207.5)
#        If (feature 4 <= 12.5)
#         Predict: 0.0
#        Else (feature 4 > 12.5)
#         Predict: 1.0
#       Else (feature 3 > 207.5)
#        If (feature 3 <= 351.5)
#         If (feature 3 <= 221.5)
#          Predict: 1.0
#         Else (feature 3 > 221.5)
#          Predict: 0.0
#        Else (feature 3 > 351.5)
#         Predict: 1.0
#     Else (feature 6 > 0.5)
#      If (feature 5 <= 192.5)
#       If (feature 3 <= 181.5)
#        Predict: 0.0
#       Else (feature 3 > 181.5)
#        If (feature 3 <= 435.5)
#         If (feature 2 <= 16.5)
#          Predict: 1.0
#         Else (feature 2 > 16.5)
#          Predict: 0.0
#        Else (feature 3 > 435.5)
#         Predict: 1.0
#      Else (feature 5 > 192.5)
#       If (feature 1 <= 934.5)
#        If (feature 2 <= 20.5)
#         If (feature 3 <= 496.5)
#          Predict: 0.0
#         Else (feature 3 > 496.5)
#          Predict: 1.0
#        Else (feature 2 > 20.5)
#         Predict: 0.0
#       Else (feature 1 > 934.5)
#        If (feature 2 <= 21.5)
#         Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 3 <= 158.5)
#          Predict: 0.0
#         Else (feature 3 > 158.5)
#          Predict: 1.0
#   Tree 11 (weight 1.0):
#     If (feature 3 <= 496.5)
#      If (feature 5 <= 9.0)
#       If (feature 3 <= 252.5)
#        Predict: 0.0
#       Else (feature 3 > 252.5)
#        If (feature 2 <= 3.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#        Else (feature 2 > 3.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#      Else (feature 5 > 9.0)
#       If (feature 0 <= 58.5)
#        If (feature 3 <= 169.5)
#         Predict: 0.0
#        Else (feature 3 > 169.5)
#         If (feature 5 <= 98.5)
#          Predict: 1.0
#         Else (feature 5 > 98.5)
#          Predict: 0.0
#       Else (feature 0 > 58.5)
#        If (feature 4 <= 1.5)
#         If (feature 2 <= 7.5)
#          Predict: 0.0
#         Else (feature 2 > 7.5)
#          Predict: 1.0
#        Else (feature 4 > 1.5)
#         If (feature 6 <= 5.5)
#          Predict: 0.0
#         Else (feature 6 > 5.5)
#          Predict: 1.0
#     Else (feature 3 > 496.5)
#      If (feature 5 <= 7.5)
#       If (feature 2 <= 15.5)
#        If (feature 1 <= 2430.5)
#         Predict: 0.0
#        Else (feature 1 > 2430.5)
#         If (feature 2 <= 11.5)
#          Predict: 0.0
#         Else (feature 2 > 11.5)
#          Predict: 1.0
#       Else (feature 2 > 15.5)
#        If (feature 0 <= 33.5)
#         If (feature 5 <= -0.5)
#          Predict: 0.0
#         Else (feature 5 > -0.5)
#          Predict: 1.0
#        Else (feature 0 > 33.5)
#         Predict: 0.0
#      Else (feature 5 > 7.5)
#       If (feature 5 <= 98.5)
#        Predict: 1.0
#       Else (feature 5 > 98.5)
#        If (feature 1 <= 5057.5)
#         If (feature 5 <= 192.5)
#          Predict: 1.0
#         Else (feature 5 > 192.5)
#          Predict: 0.0
#        Else (feature 1 > 5057.5)
#         Predict: 1.0
#   Tree 12 (weight 1.0):
#     If (feature 3 <= 435.5)
#      If (feature 6 <= 0.5)
#       Predict: 0.0
#      Else (feature 6 > 0.5)
#       If (feature 5 <= 98.5)
#        If (feature 3 <= 169.5)
#         Predict: 0.0
#        Else (feature 3 > 169.5)
#         Predict: 1.0
#       Else (feature 5 > 98.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 207.5)
#          Predict: 0.0
#         Else (feature 3 > 207.5)
#          Predict: 1.0
#     Else (feature 3 > 435.5)
#      If (feature 3 <= 692.5)
#       If (feature 6 <= 0.5)
#        If (feature 3 <= 583.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#        Else (feature 3 > 583.5)
#         Predict: 0.0
#       Else (feature 6 > 0.5)
#        If (feature 2 <= 20.5)
#         If (feature 0 <= 49.5)
#          Predict: 0.0
#         Else (feature 0 > 49.5)
#          Predict: 1.0
#        Else (feature 2 > 20.5)
#         If (feature 1 <= -103.0)
#          Predict: 0.0
#         Else (feature 1 > -103.0)
#          Predict: 1.0
#      Else (feature 3 > 692.5)
#       If (feature 1 <= 458.5)
#        If (feature 4 <= 1.5)
#         Predict: 1.0
#        Else (feature 4 > 1.5)
#         If (feature 0 <= 28.5)
#          Predict: 1.0
#         Else (feature 0 > 28.5)
#          Predict: 0.0
#       Else (feature 1 > 458.5)
#        If (feature 3 <= 920.5)
#         If (feature 2 <= 11.5)
#          Predict: 1.0
#         Else (feature 2 > 11.5)
#          Predict: 0.0
#        Else (feature 3 > 920.5)
#         If (feature 5 <= 347.5)
#          Predict: 1.0
#         Else (feature 5 > 347.5)
#          Predict: 0.0
#   Tree 13 (weight 1.0):
#     If (feature 5 <= 9.0)
#      If (feature 1 <= 235.5)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 29.5)
#         Predict: 0.0
#        Else (feature 2 > 29.5)
#         Predict: 1.0
#      Else (feature 1 > 235.5)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 193.5)
#         Predict: 0.0
#        Else (feature 3 > 193.5)
#         Predict: 1.0
#     Else (feature 5 > 9.0)
#      If (feature 3 <= 207.5)
#       If (feature 5 <= 98.5)
#        If (feature 3 <= 129.5)
#         Predict: 0.0
#        Else (feature 3 > 129.5)
#         If (feature 4 <= 2.5)
#          Predict: 1.0
#         Else (feature 4 > 2.5)
#          Predict: 0.0
#       Else (feature 5 > 98.5)
#        Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 98.5)
#        If (feature 3 <= 435.5)
#         If (feature 6 <= 12.5)
#          Predict: 1.0
#         Else (feature 6 > 12.5)
#          Predict: 0.0
#        Else (feature 3 > 435.5)
#         Predict: 1.0
#       Else (feature 5 > 98.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 1 <= 5057.5)
#          Predict: 1.0
#         Else (feature 1 > 5057.5)
#          Predict: 0.0
#   Tree 14 (weight 1.0):
#     If (feature 0 <= 60.5)
#      If (feature 3 <= 496.5)
#       Predict: 0.0
#      Else (feature 3 > 496.5)
#       If (feature 5 <= 7.5)
#        If (feature 3 <= 920.5)
#         Predict: 0.0
#        Else (feature 3 > 920.5)
#         Predict: 1.0
#       Else (feature 5 > 7.5)
#        If (feature 1 <= 5057.5)
#         If (feature 5 <= 192.5)
#          Predict: 1.0
#         Else (feature 5 > 192.5)
#          Predict: 0.0
#        Else (feature 1 > 5057.5)
#         Predict: 1.0
#     Else (feature 0 > 60.5)
#      If (feature 5 <= -0.5)
#       If (feature 3 <= 129.5)
#        Predict: 0.0
#       Else (feature 3 > 129.5)
#        If (feature 3 <= 351.5)
#         Predict: 0.0
#        Else (feature 3 > 351.5)
#         Predict: 1.0
#      Else (feature 5 > -0.5)
#       If (feature 2 <= 27.5)
#        If (feature 4 <= 1.5)
#         If (feature 3 <= 169.5)
#          Predict: 0.0
#         Else (feature 3 > 169.5)
#          Predict: 1.0
#        Else (feature 4 > 1.5)
#         If (feature 3 <= 389.5)
#          Predict: 0.0
#         Else (feature 3 > 389.5)
#          Predict: 1.0
#       Else (feature 2 > 27.5)
#        If (feature 1 <= 148.5)
#         Predict: 0.0
#        Else (feature 1 > 148.5)
#         Predict: 1.0
#   Tree 15 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 3 <= 496.5)
#       If (feature 3 <= 221.5)
#        Predict: 0.0
#       Else (feature 3 > 221.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 1 <= 3765.5)
#          Predict: 1.0
#         Else (feature 1 > 3765.5)
#          Predict: 0.0
#      Else (feature 3 > 496.5)
#       If (feature 0 <= 58.5)
#        Predict: 0.0
#       Else (feature 0 > 58.5)
#        If (feature 1 <= 7581.5)
#         If (feature 1 <= 1445.5)
#          Predict: 0.0
#         Else (feature 1 > 1445.5)
#          Predict: 1.0
#        Else (feature 1 > 7581.5)
#         Predict: 0.0
#     Else (feature 6 > 0.5)
#      If (feature 3 <= 169.5)
#       If (feature 3 <= 94.5)
#        If (feature 2 <= 1.5)
#         If (feature 6 <= 3.5)
#          Predict: 0.0
#         Else (feature 6 > 3.5)
#          Predict: 1.0
#        Else (feature 2 > 1.5)
#         Predict: 0.0
#       Else (feature 3 > 94.5)
#        Predict: 0.0
#      Else (feature 3 > 169.5)
#       If (feature 0 <= 60.5)
#        If (feature 3 <= 389.5)
#         If (feature 0 <= 25.5)
#          Predict: 1.0
#         Else (feature 0 > 25.5)
#          Predict: 0.0
#        Else (feature 3 > 389.5)
#         If (feature 5 <= 192.5)
#          Predict: 1.0
#         Else (feature 5 > 192.5)
#          Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         Predict: 1.0
#   Tree 16 (weight 1.0):
#     If (feature 3 <= 496.5)
#      If (feature 6 <= 0.5)
#       If (feature 0 <= 60.5)
#        Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 13.5)
#         If (feature 1 <= -0.5)
#          Predict: 1.0
#         Else (feature 1 > -0.5)
#          Predict: 0.0
#        Else (feature 2 > 13.5)
#         Predict: 0.0
#      Else (feature 6 > 0.5)
#       If (feature 3 <= 169.5)
#        Predict: 0.0
#       Else (feature 3 > 169.5)
#        If (feature 0 <= 58.5)
#         If (feature 5 <= 98.5)
#          Predict: 1.0
#         Else (feature 5 > 98.5)
#          Predict: 0.0
#        Else (feature 0 > 58.5)
#         If (feature 3 <= 389.5)
#          Predict: 0.0
#         Else (feature 3 > 389.5)
#          Predict: 1.0
#     Else (feature 3 > 496.5)
#      If (feature 1 <= 808.5)
#       If (feature 5 <= 39.0)
#        If (feature 4 <= 1.5)
#         If (feature 3 <= 692.5)
#          Predict: 0.0
#         Else (feature 3 > 692.5)
#          Predict: 1.0
#        Else (feature 4 > 1.5)
#         If (feature 2 <= 29.5)
#          Predict: 0.0
#         Else (feature 2 > 29.5)
#          Predict: 1.0
#       Else (feature 5 > 39.0)
#        If (feature 5 <= 98.5)
#         If (feature 1 <= 527.5)
#          Predict: 1.0
#         Else (feature 1 > 527.5)
#          Predict: 0.0
#        Else (feature 5 > 98.5)
#         If (feature 2 <= 21.5)
#          Predict: 0.0
#         Else (feature 2 > 21.5)
#          Predict: 1.0
#      Else (feature 1 > 808.5)
#       If (feature 2 <= 16.5)
#        If (feature 3 <= 692.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#        Else (feature 3 > 692.5)
#         Predict: 1.0
#       Else (feature 2 > 16.5)
#        If (feature 0 <= 58.5)
#         Predict: 0.0
#        Else (feature 0 > 58.5)
#         If (feature 1 <= 1083.5)
#          Predict: 0.0
#         Else (feature 1 > 1083.5)
#          Predict: 1.0
#   Tree 17 (weight 1.0):
#     If (feature 3 <= 496.5)
#      If (feature 0 <= 60.5)
#       If (feature 6 <= 0.5)
#        Predict: 0.0
#       Else (feature 6 > 0.5)
#        If (feature 3 <= 158.5)
#         Predict: 0.0
#        Else (feature 3 > 158.5)
#         If (feature 5 <= 98.5)
#          Predict: 1.0
#         Else (feature 5 > 98.5)
#          Predict: 0.0
#      Else (feature 0 > 60.5)
#       If (feature 6 <= 1.5)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         If (feature 1 <= 5057.5)
#          Predict: 1.0
#         Else (feature 1 > 5057.5)
#          Predict: 0.0
#       Else (feature 6 > 1.5)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         Predict: 1.0
#     Else (feature 3 > 496.5)
#      If (feature 5 <= 28.5)
#       If (feature 3 <= 692.5)
#        If (feature 0 <= 60.5)
#         Predict: 0.0
#        Else (feature 0 > 60.5)
#         If (feature 2 <= 19.5)
#          Predict: 0.0
#         Else (feature 2 > 19.5)
#          Predict: 1.0
#       Else (feature 3 > 692.5)
#        If (feature 0 <= 52.5)
#         If (feature 1 <= 108.5)
#          Predict: 0.0
#         Else (feature 1 > 108.5)
#          Predict: 1.0
#        Else (feature 0 > 52.5)
#         If (feature 2 <= 15.5)
#          Predict: 1.0
#         Else (feature 2 > 15.5)
#          Predict: 0.0
#      Else (feature 5 > 28.5)
#       If (feature 2 <= 21.5)
#        If (feature 2 <= 16.5)
#         Predict: 1.0
#        Else (feature 2 > 16.5)
#         If (feature 1 <= 527.5)
#          Predict: 1.0
#         Else (feature 1 > 527.5)
#          Predict: 0.0
#       Else (feature 2 > 21.5)
#        If (feature 1 <= -103.0)
#         Predict: 0.0
#        Else (feature 1 > -103.0)
#         Predict: 1.0
#   Tree 18 (weight 1.0):
#     If (feature 5 <= 28.5)
#      If (feature 3 <= 583.5)
#       If (feature 0 <= 60.5)
#        If (feature 2 <= 1.5)
#         If (feature 3 <= 158.5)
#          Predict: 0.0
#         Else (feature 3 > 158.5)
#          Predict: 1.0
#        Else (feature 2 > 1.5)
#         Predict: 0.0
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 13.5)
#         If (feature 1 <= -0.5)
#          Predict: 1.0
#         Else (feature 1 > -0.5)
#          Predict: 0.0
#        Else (feature 2 > 13.5)
#         If (feature 3 <= 322.5)
#          Predict: 0.0
#         Else (feature 3 > 322.5)
#          Predict: 1.0
#      Else (feature 3 > 583.5)
#       If (feature 3 <= 692.5)
#        Predict: 0.0
#       Else (feature 3 > 692.5)
#        If (feature 2 <= 29.5)
#         If (feature 5 <= 15.0)
#          Predict: 1.0
#         Else (feature 5 > 15.0)
#          Predict: 0.0
#        Else (feature 2 > 29.5)
#         If (feature 4 <= 6.5)
#          Predict: 1.0
#         Else (feature 4 > 6.5)
#          Predict: 0.0
#     Else (feature 5 > 28.5)
#      If (feature 3 <= 207.5)
#       If (feature 3 <= 129.5)
#        Predict: 0.0
#       Else (feature 3 > 129.5)
#        If (feature 5 <= 98.5)
#         If (feature 2 <= 17.5)
#          Predict: 1.0
#         Else (feature 2 > 17.5)
#          Predict: 0.0
#        Else (feature 5 > 98.5)
#         Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 98.5)
#        If (feature 2 <= 30.5)
#         Predict: 1.0
#        Else (feature 2 > 30.5)
#         If (feature 0 <= 52.5)
#          Predict: 1.0
#         Else (feature 0 > 52.5)
#          Predict: 0.0
#       Else (feature 5 > 98.5)
#        If (feature 3 <= 496.5)
#         Predict: 0.0
#        Else (feature 3 > 496.5)
#         If (feature 0 <= 36.5)
#          Predict: 1.0
#         Else (feature 0 > 36.5)
#          Predict: 0.0
#   Tree 19 (weight 1.0):
#     If (feature 3 <= 496.5)
#      If (feature 5 <= 12.5)
#       If (feature 3 <= 207.5)
#        Predict: 0.0
#       Else (feature 3 > 207.5)
#        If (feature 2 <= 2.5)
#         Predict: 0.0
#        Else (feature 2 > 2.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#      Else (feature 5 > 12.5)
#       If (feature 3 <= 169.5)
#        Predict: 0.0
#       Else (feature 3 > 169.5)
#        If (feature 0 <= 58.5)
#         Predict: 0.0
#        Else (feature 0 > 58.5)
#         If (feature 4 <= 1.5)
#          Predict: 1.0
#         Else (feature 4 > 1.5)
#          Predict: 0.0
#     Else (feature 3 > 496.5)
#      If (feature 3 <= 692.5)
#       If (feature 5 <= 7.5)
#        If (feature 3 <= 583.5)
#         If (feature 0 <= 60.5)
#          Predict: 0.0
#         Else (feature 0 > 60.5)
#          Predict: 1.0
#        Else (feature 3 > 583.5)
#         Predict: 0.0
#       Else (feature 5 > 7.5)
#        If (feature 0 <= 58.5)
#         If (feature 2 <= 20.5)
#          Predict: 0.0
#         Else (feature 2 > 20.5)
#          Predict: 1.0
#        Else (feature 0 > 58.5)
#         If (feature 1 <= 2055.0)
#          Predict: 1.0
#         Else (feature 1 > 2055.0)
#          Predict: 0.0
#      Else (feature 3 > 692.5)
#       If (feature 4 <= 11.5)
#        If (feature 1 <= 808.5)
#         If (feature 2 <= 28.5)
#          Predict: 0.0
#         Else (feature 2 > 28.5)
#          Predict: 1.0
#        Else (feature 1 > 808.5)
#         Predict: 1.0
#       Else (feature 4 > 11.5)
#        If (feature 2 <= 23.5)
#         Predict: 0.0
#        Else (feature 2 > 23.5)
#         If (feature 2 <= 25.5)
#          Predict: 1.0
#         Else (feature 2 > 25.5)
#          Predict: 0.0
